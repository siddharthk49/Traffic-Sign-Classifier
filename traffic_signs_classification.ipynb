# %%
# import libraries 
import pickle
import seaborn as sns
import pandas as pd # Import Pandas for data manipulation using dataframes
import numpy as np # Import Numpy for data statistical analysis 
import matplotlib.pyplot as plt # Import matplotlib for data visualisation
import random

# %%
# The pickle module implements binary protocols for serializing and de-serializing a Python object structure.
with open("C:/Users/siddhk/Downloads/P74-Project-5/Project 5/traffic-signs-data/train.p", mode='rb') as training_data:
    train = pickle.load(training_data)
with open("C:/Users/siddhk/Downloads/P74-Project-5/Project 5/traffic-signs-data/valid.p", mode='rb') as validation_data:
    valid = pickle.load(validation_data)
with open("C:/Users/siddhk/Downloads/P74-Project-5/Project 5/traffic-signs-data/test.p", mode='rb') as testing_data:
    test = pickle.load(testing_data)

# %%
X_train, y_train = train['features'], train['labels']
X_validation, y_validation = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %%
X_train.shape
# Out:
# (34799, 32, 32, 3)

# %%
y_train.shape
# Out:
# (34799,)

# %%
i = 1001
plt.imshow(X_train[i]) # Show images are not shuffled
y_train[i]
# Out:
# np.uint8(36)

# %%
## Shuffle the dataset 
from sklearn.utils import shuffle
X_train, y_train = shuffle(X_train, y_train)

# %%
X_train_gray = np.sum(X_train/3, axis=3, keepdims=True)
X_test_gray  = np.sum(X_test/3, axis=3, keepdims=True)
X_validation_gray  = np.sum(X_validation/3, axis=3, keepdims=True)

# %%
X_train_gray_norm = (X_train_gray - 128)/128 
X_test_gray_norm = (X_test_gray - 128)/128
X_validation_gray_norm = (X_validation_gray - 128)/128

# %%
# Import train_test_split from scikit library

from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, Dense, Flatten, Dropout
from keras.optimizers import Adam
from keras.callbacks import TensorBoard

from sklearn.model_selection import train_test_split

# %%
cnn_model = Sequential()

cnn_model.add(Conv2D(filters=6, kernel_size=(5, 5), activation='relu', input_shape=(32,32,1)))
cnn_model.add(AveragePooling2D(pool_size=(2, 2), strides=2))

cnn_model.add(Conv2D(filters=16, kernel_size=(5, 5), activation='relu'))
cnn_model.add(AveragePooling2D(pool_size=(2, 2), strides=2))

cnn_model.add(Flatten())

cnn_model.add(Dense(units=120, activation='relu'))

cnn_model.add(Dense(units=84, activation='relu'))

cnn_model.add(Dense(units=43, activation = 'softmax'))

# %%
cnn_model.compile(loss ='sparse_categorical_crossentropy', optimizer=Adam(learning_rate=0.001),metrics =['accuracy'])

# %%
history = cnn_model.fit(X_train_gray_norm,
                        y_train,
                        batch_size=500,
                        epochs=50,
                        verbose=1,
                        validation_data = (X_validation_gray_norm,y_validation))
# Out:
# Epoch 1/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.1051 - loss: 3.4536 - val_accuracy: 0.3118 - val_loss: 2.5584
# Epoch 2/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.5006 - loss: 1.8246 - val_accuracy: 0.6340 - val_loss: 1.2855
# Epoch 3/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.7275 - loss: 0.9398 - val_accuracy: 0.7222 - val_loss: 0.9304
# Epoch 4/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8179 - loss: 0.6573 - val_accuracy: 0.7751 - val_loss: 0.7568
# Epoch 5/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8609 - loss: 0.5083 - val_accuracy: 0.7986 - val_loss: 0.6928
# Epoch 6/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8896 - loss: 0.4283 - val_accuracy: 0.8166 - val_loss: 0.6251
# Epoch 7/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9086 - loss: 0.3590 - val_accuracy: 0.8245 - val_loss: 0.6168
# Epoch 8/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9193 - loss: 0.3167 - val_accuracy: 0.8118 - val_loss: 0.6321
# Epoch 9/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9291 - loss: 0.2842 - val_accuracy: 0.8354 - val_loss: 0.5596
# Epoch 10/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9414 - loss: 0.2372 - val_accuracy: 0.8424 - val_loss: 0.5590
# Epoch 11/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9429 - loss: 0.2165 - val_accuracy: 0.8603 - val_loss: 0.5176
# Epoch 12/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9492 - loss: 0.1976 - val_accuracy: 0.8515 - val_loss: 0.5249
# Epoch 13/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9531 - loss: 0.1821 - val_accuracy: 0.8506 - val_loss: 0.5414
# Epoch 14/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9612 - loss: 0.1588 - val_accuracy: 0.8410 - val_loss: 0.5857
# Epoch 15/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9644 - loss: 0.1482 - val_accuracy: 0.8587 - val_loss: 0.5188
# Epoch 16/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9675 - loss: 0.1338 - val_accuracy: 0.8605 - val_loss: 0.5283
# Epoch 17/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9694 - loss: 0.1231 - val_accuracy: 0.8651 - val_loss: 0.5080
# Epoch 18/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9727 - loss: 0.1145 - val_accuracy: 0.8662 - val_loss: 0.5445
# Epoch 19/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9755 - loss: 0.1013 - val_accuracy: 0.8664 - val_loss: 0.5258
# Epoch 20/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9783 - loss: 0.0911 - val_accuracy: 0.8626 - val_loss: 0.5838
# Epoch 21/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9785 - loss: 0.0895 - val_accuracy: 0.8594 - val_loss: 0.5983
# Epoch 22/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9796 - loss: 0.0830 - val_accuracy: 0.8540 - val_loss: 0.5760
# Epoch 23/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9815 - loss: 0.0746 - val_accuracy: 0.8515 - val_loss: 0.6383
# Epoch 24/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9860 - loss: 0.0668 - val_accuracy: 0.8689 - val_loss: 0.5777
# Epoch 25/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9863 - loss: 0.0609 - val_accuracy: 0.8615 - val_loss: 0.6229
# Epoch 26/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9855 - loss: 0.0600 - val_accuracy: 0.8646 - val_loss: 0.6289
# Epoch 27/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9876 - loss: 0.0553 - val_accuracy: 0.8662 - val_loss: 0.6538
# Epoch 28/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9883 - loss: 0.0480 - val_accuracy: 0.8628 - val_loss: 0.7066
# Epoch 29/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9885 - loss: 0.0482 - val_accuracy: 0.8660 - val_loss: 0.6887
# Epoch 30/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9903 - loss: 0.0423 - val_accuracy: 0.8730 - val_loss: 0.7048
# Epoch 31/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9898 - loss: 0.0431 - val_accuracy: 0.8753 - val_loss: 0.6573
# Epoch 32/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9909 - loss: 0.0411 - val_accuracy: 0.8723 - val_loss: 0.6610
# Epoch 33/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9912 - loss: 0.0369 - val_accuracy: 0.8685 - val_loss: 0.6584
# Epoch 34/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9907 - loss: 0.0387 - val_accuracy: 0.8683 - val_loss: 0.6918
# Epoch 35/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9931 - loss: 0.0323 - val_accuracy: 0.8737 - val_loss: 0.7508
# Epoch 36/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9913 - loss: 0.0329 - val_accuracy: 0.8635 - val_loss: 0.7562
# Epoch 37/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9935 - loss: 0.0259 - val_accuracy: 0.8707 - val_loss: 0.7636
# Epoch 38/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9940 - loss: 0.0244 - val_accuracy: 0.8671 - val_loss: 0.7139
# Epoch 39/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9936 - loss: 0.0264 - val_accuracy: 0.8642 - val_loss: 0.7921
# Epoch 40/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9940 - loss: 0.0238 - val_accuracy: 0.8594 - val_loss: 0.7458
# Epoch 41/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9938 - loss: 0.0253 - val_accuracy: 0.8794 - val_loss: 0.7857
# Epoch 42/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9957 - loss: 0.0203 - val_accuracy: 0.8796 - val_loss: 0.8270
# Epoch 43/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9965 - loss: 0.0186 - val_accuracy: 0.8719 - val_loss: 0.7478
# Epoch 44/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9961 - loss: 0.0175 - val_accuracy: 0.8703 - val_loss: 0.7702
# Epoch 45/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9942 - loss: 0.0216 - val_accuracy: 0.8712 - val_loss: 0.8130
# Epoch 46/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9961 - loss: 0.0170 - val_accuracy: 0.8596 - val_loss: 0.8326
# Epoch 47/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9941 - loss: 0.0210 - val_accuracy: 0.8794 - val_loss: 0.8003
# Epoch 48/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9972 - loss: 0.0123 - val_accuracy: 0.8807 - val_loss: 0.7349
# Epoch 49/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9972 - loss: 0.0129 - val_accuracy: 0.8773 - val_loss: 0.7963
# Epoch 50/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9969 - loss: 0.0133 - val_accuracy: 0.8841 - val_loss: 0.6906

# %%
score = cnn_model.evaluate(X_test_gray_norm, y_test,verbose=0)
print('Test Accuracy : {:.4f}'.format(score[1]))
# Out:
# Test Accuracy : 0.8740

# %%
history.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(accuracy))

plt.plot(epochs, accuracy, 'bo', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation accuracy')
plt.legend()

# %%
plt.plot(epochs, loss, 'ro', label='Training Loss')
plt.plot(epochs, val_loss, 'r', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
#get the predictions for the test data
#predicted_classes = cnn_model.predict_classes(X_test_gray_norm)
predictions = cnn_model.predict(X_test_gray_norm)
predicted_classes = np.argmax(predictions, axis=1)
#get the indices to be plotted
y_true = y_test
# Out:
# 395/395 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_true, predicted_classes)
plt.figure(figsize = (25,25))
sns.heatmap(cm, annot=True)
# Out:
# <Axes: >

# %%
L = 7
W = 7
fig, axes = plt.subplots(L, W, figsize = (12,12))
axes = axes.ravel() # 

for i in np.arange(0, L * W):  
    axes[i].imshow(X_test[i])
    axes[i].set_title("Prediction={}\n True={}".format(predicted_classes[i], y_true[i]))
    axes[i].axis('off')

plt.subplots_adjust(wspace=1)
